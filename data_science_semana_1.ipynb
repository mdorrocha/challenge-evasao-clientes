# %% [markdown]
# # Desafio Data Science - Semana 1

# %% [markdown]
# ### *Tratamento dos dados do Dataframe*

# %%
import pandas as pd

# %%
pd.set_option("display.max_columns", 100)

# %%
# leitura do arquivo json
dados = pd.read_json('dados/telco-customer-churn.json')

# %%
dados.head()
# Out:
#    customerID Churn                                           customer  \
# 0  0002-ORFBO    No  {'gender': 'Female', 'SeniorCitizen': 0, 'Part...
# 1  0003-MKNFE    No  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 2  0004-TLHLJ   Yes  {'gender': 'Male', 'SeniorCitizen': 0, 'Partne...
# 3  0011-IGKFF   Yes  {'gender': 'Male', 'SeniorCitizen': 1, 'Partne...
# 4  0013-EXCHZ   Yes  {'gender': 'Female', 'SeniorCitizen': 1, 'Part...
#
#                                              phone  \
# 0   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 1  {'PhoneService': 'Yes', 'MultipleLines': 'Yes'}
# 2   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 3   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
# 4   {'PhoneService': 'Yes', 'MultipleLines': 'No'}
#
#                                             internet  \
# 0  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 1  {'InternetService': 'DSL', 'OnlineSecurity': '...
# 2  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 3  {'InternetService': 'Fiber optic', 'OnlineSecu...
# 4  {'InternetService': 'Fiber optic', 'OnlineSecu...
#
#                                              account
# 0  {'Contract': 'One year', 'PaperlessBilling': '...
# 1  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 2  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 3  {'Contract': 'Month-to-month', 'PaperlessBilli...
# 4  {'Contract': 'Month-to-month', 'PaperlessBilli...

# %%
# números de linhas e colunas
print('Total de linhas: ' + str(dados.shape[0]))
print('Total de colunas: ' + str(dados.shape[1]))
# Out:
# Total de linhas: 7267
# Total de colunas: 6

# %%
# normalizando a coluna customer
customer = pd.json_normalize(data=dados.customer)

# %%
# normalizando a coluna phone
phone = pd.json_normalize(data=dados.phone)

# %%
# normalizando a coluna internet
internet = pd.json_normalize(data=dados.internet)

# %%
# normalizando a coluna account
account = pd.json_normalize(data=dados.account)

# %%
# juntando os dataframes
dados_combinados = pd.concat([dados, customer, phone, internet, account], axis=1)

# %%
# eliminando colunas redundantes
dados_combinados = dados_combinados.drop(['customer', 'phone', 'internet', 'account'], axis=1)
dados_combinados.head()
# Out:
#    customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0  0002-ORFBO    No  Female              0     Yes        Yes       9
# 1  0003-MKNFE    No    Male              0      No         No       9
# 2  0004-TLHLJ   Yes    Male              0      No         No       4
# 3  0011-IGKFF   Yes    Male              1     Yes         No      13
# 4  0013-EXCHZ   Yes  Female              1     Yes         No       3
#
#   PhoneService MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0          Yes            No             DSL             No          Yes
# 1          Yes           Yes             DSL             No           No
# 2          Yes            No     Fiber optic             No           No
# 3          Yes            No     Fiber optic             No          Yes
# 4          Yes            No     Fiber optic             No           No
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No         Yes         Yes              No        One year
# 1               No          No          No             Yes  Month-to-month
# 2              Yes          No          No              No  Month-to-month
# 3              Yes          No         Yes             Yes  Month-to-month
# 4               No         Yes         Yes              No  Month-to-month
#
#   PaperlessBilling     PaymentMethod  Charges.Monthly Charges.Total
# 0              Yes      Mailed check             65.6         593.3
# 1               No      Mailed check             59.9         542.4
# 2              Yes  Electronic check             73.9        280.85
# 3              Yes  Electronic check             98.0       1237.85
# 4              Yes      Mailed check             83.9         267.4

# %%
# pesquisar dados nulos
dados_combinados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7267 entries, 0 to 7266
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7267 non-null   object
#  1   Churn             7267 non-null   object
#  2   gender            7267 non-null   object
#  3   SeniorCitizen     7267 non-null   int64
#  4   Partner           7267 non-null   object
#  5   Dependents        7267 non-null   object
#  6   tenure            7267 non-null   int64
#  7   PhoneService      7267 non-null   object
#  8   MultipleLines     7267 non-null   object
#  9   InternetService   7267 non-null   object
#  10  OnlineSecurity    7267 non-null   object
#  11  OnlineBackup      7267 non-null   object
#  12  DeviceProtection  7267 non-null   object
#  13  TechSupport       7267 non-null   object
#  14  StreamingTV       7267 non-null   object
#  15  StreamingMovies   7267 non-null   object
#  16  Contract          7267 non-null   object
#  17  PaperlessBilling  7267 non-null   object
#  18  PaymentMethod     7267 non-null   object
#  19  Charges.Monthly   7267 non-null   float64
#  20  Charges.Total     7267 non-null   object
# dtypes: float64(1), int64(2), object(18)
# memory usage: 1.2+ MB

# %%
# analisando os dados das colunas
for column in dados_combinados.columns:
    print(column, dados_combinados[column].unique())
# Out:
# customerID ['0002-ORFBO' '0003-MKNFE' '0004-TLHLJ' ... '9992-UJOEL' '9993-LHIEB'
#  '9995-HOTOH']
# Churn ['No' 'Yes' '']
# gender ['Female' 'Male']
# SeniorCitizen [0 1]
# Partner ['Yes' 'No']
# Dependents ['Yes' 'No']
# tenure [ 9  4 13  3 71 63  7 65 54 72  5 56 34  1 45 50 23 55 26 69 11 37 49 66
#  67 20 43 59 12 27  2 25 29 14 35 64 39 40  6 30 70 57 58 16 32 33 10 21
#  61 15 44 22 24 19 47 62 46 52  8 60 48 28 41 53 68 51 31 36 17 18 38 42
#   0]
# PhoneService ['Yes' 'No']
# MultipleLines ['No' 'Yes' 'No phone service']
# InternetService ['DSL' 'Fiber optic' 'No']
# OnlineSecurity ['No' 'Yes' 'No internet service']
# OnlineBackup ['Yes' 'No' 'No internet service']
# DeviceProtection ['No' 'Yes' 'No internet service']
# TechSupport ['Yes' 'No' 'No internet service']
# StreamingTV ['Yes' 'No' 'No internet service']
# StreamingMovies ['No' 'Yes' 'No internet service']
# Contract ['One year' 'Month-to-month' 'Two year']
# PaperlessBilling ['Yes' 'No']
# PaymentMethod ['Mailed check' 'Electronic check' 'Credit card (automatic)'
#  'Bank transfer (automatic)']
# Charges.Monthly [65.6  59.9  73.9  ... 91.75 68.8  67.85]
# Charges.Total ['593.3' '542.4' '280.85' ... '742.9' '4627.65' '3707.6']

# %%
# convertendo a coluna Charges.Total para float
dados_combinados['Charges.Total'].replace(' ', '0', inplace=True)
dados_combinados['Charges.Total'] = dados_combinados['Charges.Total'].astype({'Charges.Total': 'float64'})

# %%
# total de registros cujo valor em Churn é vazio
churn_vazio = dados_combinados.Churn == ''
dados_combinados[churn_vazio].shape[0]
# Out:
# 224

# %%
# eliminando registros cujo valor em Churn é vazio
dados_combinados.drop(dados_combinados[churn_vazio].index, inplace=True)

# %%
# reindexando o dataframe
new_index = range(dados_combinados.shape[0])
dados_combinados = dados_combinados.reindex(new_index)
dados_combinados
# Out:
#       customerID Churn  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     0002-ORFBO    No  Female            0.0     Yes        Yes     9.0
# 1     0003-MKNFE    No    Male            0.0      No         No     9.0
# 2     0004-TLHLJ   Yes    Male            0.0      No         No     4.0
# 3     0011-IGKFF   Yes    Male            1.0     Yes         No    13.0
# 4     0013-EXCHZ   Yes  Female            1.0     Yes         No     3.0
# ...          ...   ...     ...            ...     ...        ...     ...
# 7038  9695-IDRZR    No  Female            0.0      No        Yes    34.0
# 7039  9696-RMYBA    No    Male            0.0      No         No     5.0
# 7040  9699-UBQFS    No  Female            1.0     Yes         No    43.0
# 7041  9700-ISPUP    No  Female            0.0     Yes        Yes    10.0
# 7042  9700-ZCLOT    No    Male            0.0      No         No     2.0
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 0             Yes            No             DSL                   No
# 1             Yes           Yes             DSL                   No
# 2             Yes            No     Fiber optic                   No
# 3             Yes            No     Fiber optic                   No
# 4             Yes            No     Fiber optic                   No
# ...           ...           ...             ...                  ...
# 7038          Yes           Yes     Fiber optic                  Yes
# 7039          Yes            No     Fiber optic                   No
# 7040          Yes           Yes     Fiber optic                  Yes
# 7041          Yes            No             DSL                   No
# 7042          Yes            No              No  No internet service
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 0                     Yes                   No                  Yes
# 1                      No                   No                   No
# 2                      No                  Yes                   No
# 3                     Yes                  Yes                   No
# 4                      No                   No                  Yes
# ...                   ...                  ...                  ...
# 7038                  Yes                  Yes                  Yes
# 7039                   No                   No                   No
# 7040                  Yes                   No                   No
# 7041                  Yes                   No                  Yes
# 7042  No internet service  No internet service  No internet service
#
#               StreamingTV      StreamingMovies        Contract  \
# 0                     Yes                   No        One year
# 1                      No                  Yes  Month-to-month
# 2                      No                   No  Month-to-month
# 3                     Yes                  Yes  Month-to-month
# 4                     Yes                   No  Month-to-month
# ...                   ...                  ...             ...
# 7038                  Yes                  Yes        Two year
# 7039                  Yes                   No  Month-to-month
# 7040                  Yes                   No  Month-to-month
# 7041                   No                  Yes  Month-to-month
# 7042  No internet service  No internet service  Month-to-month
#
#      PaperlessBilling            PaymentMethod  Charges.Monthly  Charges.Total
# 0                 Yes             Mailed check            65.60         593.30
# 1                  No             Mailed check            59.90         542.40
# 2                 Yes         Electronic check            73.90         280.85
# 3                 Yes         Electronic check            98.00        1237.85
# 4                 Yes             Mailed check            83.90         267.40
# ...               ...                      ...              ...            ...
# 7038              Yes  Credit card (automatic)           116.15        3946.90
# 7039              Yes             Mailed check            80.10         398.55
# 7040              Yes         Electronic check            94.50        4156.80
# 7041              Yes         Electronic check            65.50         616.90
# 7042               No             Mailed check            20.00          32.70
#
# [7043 rows x 21 columns]

# %%
#traduzindo as colunas
colunas_traduzidas = ['Id Cliente', 'Cancelou', 'Gênero', 'Maior igual a 65', 'Parceiro', 'Dependentes', 
'Meses de contrato', 'Serviço telefônico', 'Múltiplas linhas', 'Serviço de internet', 'Segurança online', 
'Backup online', 'Proteção do dispositivo', 'Suporte técnico', 'TV a cabo', 'Streaming de filmes', 
'Tipo de contrato', 'Fatura online', 'Forma de pagamento', 'Valor por mês', 'Valor total']
dados_combinados.columns = colunas_traduzidas
dados_combinados.head()
# Out:
#    Id Cliente Cancelou  Gênero  Maior igual a 65 Parceiro Dependentes  \
# 0  0002-ORFBO       No  Female               0.0      Yes         Yes
# 1  0003-MKNFE       No    Male               0.0       No          No
# 2  0004-TLHLJ      Yes    Male               0.0       No          No
# 3  0011-IGKFF      Yes    Male               1.0      Yes          No
# 4  0013-EXCHZ      Yes  Female               1.0      Yes          No
#
#    Meses de contrato Serviço telefônico Múltiplas linhas Serviço de internet  \
# 0                9.0                Yes               No                 DSL
# 1                9.0                Yes              Yes                 DSL
# 2                4.0                Yes               No         Fiber optic
# 3               13.0                Yes               No         Fiber optic
# 4                3.0                Yes               No         Fiber optic
#
#   Segurança online Backup online Proteção do dispositivo Suporte técnico  \
# 0               No           Yes                      No             Yes
# 1               No            No                      No              No
# 2               No            No                     Yes              No
# 3               No           Yes                     Yes              No
# 4               No            No                      No             Yes
#
#   TV a cabo Streaming de filmes Tipo de contrato Fatura online  \
# 0       Yes                  No         One year           Yes
# 1        No                 Yes   Month-to-month            No
# 2        No                  No   Month-to-month           Yes
# 3       Yes                 Yes   Month-to-month           Yes
# 4       Yes                  No   Month-to-month           Yes
#
#   Forma de pagamento  Valor por mês  Valor total
# 0       Mailed check           65.6       593.30
# 1       Mailed check           59.9       542.40
# 2   Electronic check           73.9       280.85
# 3   Electronic check           98.0      1237.85
# 4       Mailed check           83.9       267.40

# %%
# incluindo a coluna Gastos diários
dados_combinados.insert(19, 'Gastos diários', value=round(dados_combinados['Valor por mês']/30, 2))
dados_combinados
# Out:
#       Id Cliente Cancelou  Gênero  Maior igual a 65 Parceiro Dependentes  \
# 0     0002-ORFBO       No  Female               0.0      Yes         Yes
# 1     0003-MKNFE       No    Male               0.0       No          No
# 2     0004-TLHLJ      Yes    Male               0.0       No          No
# 3     0011-IGKFF      Yes    Male               1.0      Yes          No
# 4     0013-EXCHZ      Yes  Female               1.0      Yes          No
# ...          ...      ...     ...               ...      ...         ...
# 7038  9695-IDRZR       No  Female               0.0       No         Yes
# 7039  9696-RMYBA       No    Male               0.0       No          No
# 7040  9699-UBQFS       No  Female               1.0      Yes          No
# 7041  9700-ISPUP       No  Female               0.0      Yes         Yes
# 7042  9700-ZCLOT       No    Male               0.0       No          No
#
#       Meses de contrato Serviço telefônico Múltiplas linhas  \
# 0                   9.0                Yes               No
# 1                   9.0                Yes              Yes
# 2                   4.0                Yes               No
# 3                  13.0                Yes               No
# 4                   3.0                Yes               No
# ...                 ...                ...              ...
# 7038               34.0                Yes              Yes
# 7039                5.0                Yes               No
# 7040               43.0                Yes              Yes
# 7041               10.0                Yes               No
# 7042                2.0                Yes               No
#
#      Serviço de internet     Segurança online        Backup online  \
# 0                    DSL                   No                  Yes
# 1                    DSL                   No                   No
# 2            Fiber optic                   No                   No
# 3            Fiber optic                   No                  Yes
# 4            Fiber optic                   No                   No
# ...                  ...                  ...                  ...
# 7038         Fiber optic                  Yes                  Yes
# 7039         Fiber optic                   No                   No
# 7040         Fiber optic                  Yes                  Yes
# 7041                 DSL                   No                  Yes
# 7042                  No  No internet service  No internet service
#
#      Proteção do dispositivo      Suporte técnico            TV a cabo  \
# 0                         No                  Yes                  Yes
# 1                         No                   No                   No
# 2                        Yes                   No                   No
# 3                        Yes                   No                  Yes
# 4                         No                  Yes                  Yes
# ...                      ...                  ...                  ...
# 7038                     Yes                  Yes                  Yes
# 7039                      No                   No                  Yes
# 7040                      No                   No                  Yes
# 7041                      No                  Yes                   No
# 7042     No internet service  No internet service  No internet service
#
#       Streaming de filmes Tipo de contrato Fatura online  \
# 0                      No         One year           Yes
# 1                     Yes   Month-to-month            No
# 2                      No   Month-to-month           Yes
# 3                     Yes   Month-to-month           Yes
# 4                      No   Month-to-month           Yes
# ...                   ...              ...           ...
# 7038                  Yes         Two year           Yes
# 7039                   No   Month-to-month           Yes
# 7040                   No   Month-to-month           Yes
# 7041                  Yes   Month-to-month           Yes
# 7042  No internet service   Month-to-month            No
#
#            Forma de pagamento  Gastos diários  Valor por mês  Valor total
# 0                Mailed check            2.19          65.60       593.30
# 1                Mailed check            2.00          59.90       542.40
# 2            Electronic check            2.46          73.90       280.85
# 3            Electronic check            3.27          98.00      1237.85
# 4                Mailed check            2.80          83.90       267.40
# ...                       ...             ...            ...          ...
# 7038  Credit card (automatic)            3.87         116.15      3946.90
# 7039             Mailed check            2.67          80.10       398.55
# 7040         Electronic check            3.15          94.50      4156.80
# 7041         Electronic check            2.18          65.50       616.90
# 7042             Mailed check            0.67          20.00        32.70
#
# [7043 rows x 22 columns]

# %%
# salvando o DataFrame
dados_combinados.to_csv('Dados/dados_tratados.csv', index=False)
